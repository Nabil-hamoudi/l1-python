# %% [markdown]
# Qu'est-ce qu'un pixel ?
#
# Quel format de stockage utilise-t-on ?

# %% [markdown]
# # Matrices

# %% [markdown]
# Créer une matrice avec 3 lignes et 4 colonnes

# %%
#définir la matrice sans utiliser de boucles
mat=[[-1 for i in range(3)] for n in range(4)]

# %% [markdown]
# Faire une fonction `nbrCol(matrice)` qui retourne le nombre de colonnes d'une matrice
# et une fonction `nbrLig(matrice)` qui retourne le nombre de lignes d'une matrice

# %%
def nbrCol(matrice):
    return(len(matrice))

def nbrLig(matrice):
    return(len(matrice[0]))

nbrCollone = nbrCol(mat)
nbrLine = nbrLig(mat)

# %% [markdown]
# Remplir la matrice précédente de 9 en utilisant deux boucles sur les index de la matrice.

# %%
def rempli9(matrice):
    for i in range(nbrLig(matrice)):
        for j in range(nbrCol(matrice)):
            matrice[i][j] = 9

rempli9(mat)
print(mat)
# Out:
# [[9, 9, 9], [9, 9, 9], [9, 9, 9], [9, 9, 9]]

# %% [markdown]
# Maintenant, remplir la matrice de 8 en parcourant les lignes, puis une boucle avec un index sur chacune de ces lignes.

# %%
def rempli8(matrice):
    for i in range(nbrLig(matrice)):
        for j in range(nbrCol(matrice)):
            matrice[i][j] = 8
    return matrice

print(rempli8(mat))
# Out:
# [[8, 8, 8], [8, 8, 8], [8, 8, 8], [8, 8, 8]]

# %% [markdown]
# Créer une matrice de taille 50x50 qui ne contient que des 3.

# %%
mat=[[3 for i in range(50)] for n in range(50)]

# %% [markdown]
# # Matrice de Pixels

# %% [markdown]
# Importer les librairies suivantes :

# %%
import tkinter as tk
import PIL as pil
from PIL import Image
from PIL import ImageTk 
from tkinter import filedialog
from tkinter import simpledialog

# %% [markdown]
# Ajouter la fonction suivante à votre code, on ne demande pas de la comprendre en détail.
# Elle permet de stocker la matrice de pixels passée en paramètre `matPix` dans un fichier spécifié par `filename`.

# %%
def saving(matPix, filename):
    toSave=pil.Image.new("RGBA",(nbrCol(matPix),nbrLig(matPix)))
    for i in range(nbrCol(matPix)):
        for j in range(nbrLig(matPix)):
            toSave.putpixel((i,j),matPix[j][i])
    toSave.save(filename)

# %% [markdown]
# Créer une matrice de pixels de taille 100x100 ainsi qu'une fonction qui rempli de pixels verts dans la moitié gauche et bleue dans la moitié droite de la matrice.
# Afin de visualiser l'image obtenue, on utilisera la fonction `saving` et on ouvre le fichier ainsi généré.

# %%
matVB=[[(0, 0, 0, 0)for i in range(100)] for n in range(100)]
def rempliVB(matrice):
    midle = nbrCol(matrice) // 2
    Lin = nbrLig(matrice)
    for i in range(nbrCol(matrice) // 2):
        matrice[i] = [(0, 255, 0, 255)for i in range(Lin)]
        matrice[i + midle] = [(0, 0, 255, 255)for i in range(Lin)]
    return matrice

rempliVB(matVB)
saving(matVB, "vertbleu.png")

# %% [markdown]
# Ajouter la fonction `loading` à votre code. Là non plus on ne demande pas de comprendre la fonction en détail.
# Elle prend une image en entrée et retourne une matrice de pixels.

# %%
def loading(filename):
    toLoad=pil.Image.open(filename)
    mat=[[(255,255,255,255)]*toLoad.size[0] for k in range(toLoad.size[1])]
    for i in range(toLoad.size[1]):
        for j in range(toLoad.size[0]):
            mat[i][j]=toLoad.getpixel((j,i))
    return mat

# %% [markdown]
# En vous servant de la fonction 'loading', calculer le nombre de pixels dans une image `.bmp` de votre choix, puis calculer la taille de l'image en octets. Comparer avec la taille donnée par votre machine.

# %%
mat=loading("TestBMP.bmp")
taille = nbrCol(mat) * nbrLig(mat)
print(taille)
#taille de l'image = nombre de pixels x taille d'un pixel en octet
# Out:
# 416240

# %% [markdown]
# A l'aide de la fonction `loading`, modifier une image en ajoutant un rectangle noir au milieu de l'image.

# %%
matrice=loading("vertbleu.png")

def ajouteCarreNoir(matrice):
    midle = (nbrCol(matrice) - 50) // 2
    Lin = nbrLig(matrice)
    Col = nbrCol(mtrice)
    middle_lin = (Lin - 50) // 2
    for i in range(50):
        for n in range(50) :
        matrice[i + midle][]

    
ajouteCarreNoir(matrice)
saving(matrice,"vertbleumodif.png")
# Out:
# [[(0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255)], [(0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255)], [(0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255), (0, 255, 0, 255) ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-105-3fee25d9b207> in <module>
#      12
#      13 ajouteCarreNoir(matrice)
# ---> 14 saving(matrice,"vertbleumodif.png")
#
# <ipython-input-62-2c79f7739390> in saving(matPix, filename)
#       3     for i in range(nbrCol(matPix)):
#       4         for j in range(nbrLig(matPix)):
# ----> 5             toSave.putpixel((i,j),matPix[j][i])
#       6     toSave.save(filename)
#
# IndexError: list index out of range

# %% [markdown]
# De la même manière ajouter un filtre vert sur l'image.

# %%
 matrice=loading("CExempleFas.png")

def filtre_vert(mat):
    null

#filtre_vert(matrice)
#saving(matrice,"CEFvert.png")

# %% [markdown]
# Créer une méthode qui permet d'afficher le négatif de l'image.

# %%
 matrice=loading("CExempleFas.png")

def negatif(mat):   
    null

#negatif(matrice)
#saving(matrice,"CEFnegatif.png")

# %% [markdown]
# Créer une méthode qui permet d'afficher le symétrique de l'image par rapport à la droite verticale en son milieu.

# %%
 matrice=loading("CExempleFas.png")

def symetrique(mat):   
    null

#symetrique(matrice)
#saving(matrice,"CEFSym.png")
